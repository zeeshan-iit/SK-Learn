# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.DataFrame({
    "Gender" : ["Male", "Female", "Female","Male", "Female", "Male","Male", "Female", "Female"],
    "Pass" : ["Yes", "No", "Yes", "NO", "NO", "NO", "Yes", "Yes", "No"]
})

# %%
le = LabelEncoder()

# %%
data["Enc_Gender"] = le.fit_transform(data[["Gender", "Pass"]])
# data["Enc_Pass"] = le.fit_transform(data["Pass"])

# %%
data
# Out:
#    Gender Pass  Enc_Gender  Enc_Pass
# 0    Male  Yes           1         2
# 1  Female   No           0         1
# 2  Female  Yes           0         2
# 3    Male   NO           1         0
# 4  Female   NO           0         0
# 5    Male   NO           1         0
# 6    Male  Yes           1         2
# 7  Female  Yes           0         2
# 8  Female   No           0         1
